# %% [markdown]
# # Female Candidates

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from scipy.spatial.distance import pdist, squareform
from scipy.spatial import procrustes
from scipy.stats import zscore
from sklearn.decomposition import PCA
from importlib.metadata import version

# python source path
sys.path.append('../Src/')
# Set seed
SEED = 1776

# custom python
import plot
import utilities as u

# Create a dictionary of versions
versions = {
    "Python": sys.version.split()[0],
    "Pandas": pd.__version__,
    "NumPy": np.__version__,
    "Seaborn": sns.__version__,
    "Matplot": sys.modules['matplotlib'].__version__,
    "Sk-Learn": sys.modules['sklearn'].__version__,
    "Scipy": sys.modules['scipy'].__version__,
}

# Display as a clean DataFrame
df_versions = pd.DataFrame(list(versions.items()), columns=['Library', 'Version'])
print(df_versions)

# display all columns
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_colwidth', None)

# Remove scientific notation
np.set_printoptions(suppress=True, precision=4, linewidth=100)
# reset options
# pd.reset_option('display.max_columns')
# Out:
#     Library  Version
# 0    Python  3.11.13
# 1    Pandas    2.3.1
# 2     NumPy    2.3.2
# 3   Seaborn   0.13.2
# 4   Matplot   3.10.5
# 5  Sk-Learn    1.7.1
# 6     Scipy   1.16.1

# %% [markdown]
# ## Import Data

# %%
# import data
df = pd.read_pickle("../Data/Female_CAN_Heart_PreML.pkl")
mapping_df = pd.read_pickle("../Data/Female_CAN_Heart_Mapping.pkl")
# display shape
df.shape, mapping_df.shape
# Out:
# ((8064, 104), (78, 18))

# %%
# check for NaNs
u.any_nans(df)
# Out:
# Clean Dataset: No NaNs found across 8,064 rows.
